# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhics/AI_ML_EX/blob/basic/ai_ml_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generate some synthetic data
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Create a Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X, y)

# Make predictions
X_new = np.array([[0], [2]])
y_predict = model.predict(X_new)

# Plot the results
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Simple Linear Regression Example")
plt.show()

print("Model coefficients:")
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_)
# Out:
# Model coefficients:
# Intercept: [4.22215108]
# Coefficient: [[2.96846751]]
